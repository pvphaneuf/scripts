# %%
import pandas as pd

# %%
md_df = pd.read_csv("/home/pphaneuf/GYD_metadata_spreadsheet.csv", header=1)
md_df
# Out:
#              creator          creator-email experiment data-type run-date  \
# 0    Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 1    Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 2    Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 3    Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 4    Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 5    Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 6    Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 7    Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 8    Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 9    Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 10   Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# 11   Patrick Phaneuf  pphaneuf@eng.ucsd.edu        GYD   DNA-seq  8/22/17
# ...
